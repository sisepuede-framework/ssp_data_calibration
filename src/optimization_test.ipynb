# %%
import pandas as pd
from utilities.utils import SectoralDiffReport, NonEnergySectoralDiffReport

# %%
# %load_ext autoreload
# %autoreload 2

# %%
simulation_df =  pd.read_csv('misc/model_output_dummy.csv')

# %%
simulation_df.head()
# Out:
#    time_period  area_agrc_crops_bevs_and_spices  area_agrc_crops_cereals  \
# 0            0                    110043.027838            128367.884973
# 1            1                    109457.342995            127684.669271
# 2            2                    108873.872047            127004.036131
# 3            3                    108292.613443            126325.983745
# 4            4                    107713.565838            125650.510542
#
#    area_agrc_crops_fibers  area_agrc_crops_fruits  \
# 0           110668.609194           122683.296555
# 1           110079.594803           122030.336084
# 2           109492.806893           121379.843811
# 3           108908.243904           120731.818006
# 4           108325.904482           120086.257169
#
#    area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                    125717.365902         109949.939767
# 1                                    125048.257125         109364.750368
# ...

# %%
simulation_df[simulation_df.time_period == 0].head()
# Out:
#    time_period  area_agrc_crops_bevs_and_spices  area_agrc_crops_cereals  \
# 0            0                    110043.027838            128367.884973
#
#    area_agrc_crops_fibers  area_agrc_crops_fruits  \
# 0           110668.609194           122683.296555
#
#    area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                    125717.365902         109949.939767
#
#    area_agrc_crops_other_annual  area_agrc_crops_other_woody_perennial  \
# 0                 110523.039732                           108947.99422
#
#    area_agrc_crops_pulses  ...  yield_agrc_fruits_tonne  \
# 0           107864.731825  ...            801546.441369
#
#    yield_agrc_herbs_and_other_perennial_crops_tonne  yield_agrc_nuts_tonne  \
# 0                                      4.836125e+06           91348.145737
#
#    yield_agrc_other_annual_tonne  yield_agrc_other_woody_perennial_tonne  \
# ...

# %%
sdr = SectoralDiffReport('misc', iso_alpha_3='HRV', init_year=2015)

# %%
detailed_df, subsector_df = sdr.generate_diff_reports(simulation_df)
# Out:
# The following variables from Vars are not present in simulation_df:
# emission_co2e_co2_entc_processing_and_refinement_fp_hydrogen_electrolysis
# emission_co2e_n2o_entc_generation_pp_biomass
# emission_co2e_ch4_entc_generation_pp_solar
# emission_co2e_ch4_entc_processing_and_refinement_fp_ammonia_production
# emission_co2e_n2o_entc_generation_pp_oil
# emission_co2e_n2o_entc_fuel_mining_and_extraction_me_crude
# emission_co2e_n2o_entc_generation_pp_solar
# emission_co2e_n2o_fgtv_fuel_coal
# emission_co2e_co2_fgtv_fuel_coal
# emission_co2e_n2o_entc_generation_pp_coal
# emission_co2e_n2o_entc_generation_pp_geothermal
# emission_co2e_co2_entc_generation_pp_ocean
# emission_co2e_ch4_entc_generation_pp_biomass
# emission_co2e_ch4_entc_processing_and_refinement_fp_hydrogen_gasification
# emission_co2e_n2o_entc_generation_pp_coal_ccs
# emission_co2e_ch4_entc_generation_pp_ocean
# emission_co2e_n2o_entc_processing_and_refinement_fp_hydrogen_gasification
# ...

# %%
nesdr = NonEnergySectoralDiffReport('misc', iso_alpha_3='HRV', init_year=2015)

# %%
detailed_df, subsector_df = nesdr.generate_diff_reports(simulation_df)
# Out:
# All variables from Vars are present in simulation_df.
# /home/tony/ssp/ssp_data_calibration/src/utilities/utils.py:472: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7347968751947986' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   detailed_report_draft_df.at[index, 'Simulation_Values'] = subsector_total_emissions

# %%
detailed_df
# Out:
#     Year Subsector                       Edgar_Class  Simulation_Values  \
# 0   2015      agrc                    AG - Crops:CH4           0.646705
# 1   2015      agrc                    AG - Crops:CO2          71.389678
# 2   2015      agrc                    AG - Crops:N2O           3.154383
# 3   2015      frst          LULUCF - Forest Land:CH4           0.146750
# 4   2015      frst          LULUCF - Forest Land:CO2           0.749664
# 5   2015      ippu     IN - Industrial Processes:CH4           0.026504
# 6   2015      ippu     IN - Industrial Processes:CO2           4.075408
# 7   2015      ippu     IN - Industrial Processes:HFC           1.652397
# 8   2015      ippu     IN - Industrial Processes:N2O           1.104636
# 9   2015      ippu     IN - Industrial Processes:PFC           0.000008
# 10  2015      ippu     IN - Industrial Processes:SF6           0.000000
# 11  2015      lndu        LULUCF - Deforestation:CH4           0.356581
# ...

# %%
detailed_df.dropna()
# Out:
#     Year Subsector                       Edgar_Class  Simulation_Values  \
# 0   2015      agrc                    AG - Crops:CH4           0.646705
# 1   2015      agrc                    AG - Crops:CO2          71.389678
# 2   2015      agrc                    AG - Crops:N2O           3.154383
# 4   2015      frst          LULUCF - Forest Land:CO2           0.749664
# 5   2015      ippu     IN - Industrial Processes:CH4           0.026504
# 6   2015      ippu     IN - Industrial Processes:CO2           4.075408
# 7   2015      ippu     IN - Industrial Processes:HFC           1.652397
# 8   2015      ippu     IN - Industrial Processes:N2O           1.104636
# 9   2015      ippu     IN - Industrial Processes:PFC           0.000008
# 10  2015      ippu     IN - Industrial Processes:SF6           0.000000
# 12  2015      lndu        LULUCF - Deforestation:CO2           0.182558
# 13  2015      lsmm                AG - Livestock:CH4           0.454791
# ...
